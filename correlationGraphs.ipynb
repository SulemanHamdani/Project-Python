# %%
import pandas as pd

# %%
#load data.csv
data = pd.read_csv('final_data.csv')

# %%
# Make a bar graph of the religion column where it says Atheist vs 1.1 Do you think religion provides the complete code of conduct of a person’s life?
import matplotlib.pyplot as plt
import seaborn as sns

# %%
colors = ['Yes', 'No', 'To some extent', "I’ve never heard about the Aurat March.", "Positive", "Negative", "Indifferent/not have any reaction"]
palette_colors = sns.color_palette('Set2', 7)
palette_dict = {continent: color for continent, color in zip(colors, palette_colors)}

# %%
def with_hue(ax, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in ax.patches]
    patch = [p for p in ax.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 15)

# %% [markdown]
# # Religion vs No Religion
# Differences in different religion followers:

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Religion', hue='1.1 Do you think religion provides the complete code of conduct of a person’s life?', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.1 Do you think religion provides the complete code of conduct of a person’s life?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data["Religion"], 4, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Religion', hue='1.2 Do you think religious freedom is everyone’s right? ', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.2 Do you think religious freedom is everyone’s right? ', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Religion, 4, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Religion', hue='1.4 Do you think people who wear modest clothes appear to be more moral.', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.4 Do you think people who wear modest clothes appear to be more moral.', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Religion, 4, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Religion', hue='2.8 Do you think concerts/parties are spreading vulgarity in our society?', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.8 Do you think concerts/parties are spreading vulgarity in our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Religion, 4, 3)

# %% [markdown]
# # Gender

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='1.4 Do you think people who wear modest clothes appear to be more moral.', data=data, palette=palette_dict)
plt.legend(loc="upper left")
plt.title('1.4 Do you think people who wear modest clothes appear to be more moral.', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Gender, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.4 Patriarchy is a social system in which men hold primary power and predominate in roles of moral authority.\n\nWere you aware of the term patriarchy before reading this definition?', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.4 Patriarchy is a social system in which men hold primary power and predominate in roles of moral authority.\n\nWere you aware of the term patriarchy before reading this definition?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Gender, 2, 2)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.5 Do you believe patriarchy is a necessary/effective type of social system?', data=data, palette=palette_dict)
plt.legend(loc="upper left")
plt.title('2.5 Do you believe patriarchy is a necessary/effective type of social system?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Gender, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.6 If you live in Pakistan, do you think Aurat March has negatively targeted the moral values of our society?', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.6 If you live in Pakistan, do you think Aurat March has negatively targeted the moral values of our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Gender, 2, 4)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.3 Women, transgenders, minorities are given equal rights in the society you live in.', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.3 Women, transgenders, minorities are given equal rights in the society you live in.', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Gender, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.8 Do you think concerts/parties are spreading vulgarity in our society?', data=data, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.8 Do you think concerts/parties are spreading vulgarity in our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, data.Gender, 2, 3)

# %% [markdown]
# ## Females who believe patriarchy is not necessary

# %%
females = data
females = females[data['Gender'] == 'Female']
females_patriarchy_no = females
females_patriarchy_no = females_patriarchy_no[females['2.5 Do you believe patriarchy is a necessary/effective type of social system?'] == 'No']

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.8 Do you think concerts/parties are spreading vulgarity in our society?', data=females_patriarchy_no, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.8 Do you think concerts/parties are spreading vulgarity in our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, females_patriarchy_no.Gender, 1, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.6 If you live in Pakistan, do you think Aurat March has negatively targeted the moral values of our society?', data=females_patriarchy_no, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.6 If you live in Pakistan, do you think Aurat March has negatively targeted the moral values of our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, females_patriarchy_no.Gender, 1, 4)

# %% [markdown]
# ## Females who believe Patiarchy is necessary

# %%
females_patriarchy_yes = females
females_patriarchy_yes = females_patriarchy_yes[females['2.5 Do you believe patriarchy is a necessary/effective type of social system?'] == 'Yes']

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.8 Do you think concerts/parties are spreading vulgarity in our society?', data=females_patriarchy_yes, palette=palette_dict)
plt.legend(loc="upper left")
plt.title('2.8 Do you think concerts/parties are spreading vulgarity in our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, females_patriarchy_yes.Gender, 1, 2)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Gender', hue='2.6 If you live in Pakistan, do you think Aurat March has negatively targeted the moral values of our society?', data=females_patriarchy_yes, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.6 If you live in Pakistan, do you think Aurat March has negatively targeted the moral values of our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, females_patriarchy_yes.Gender, 1, 2)

# %% [markdown]
# # Above 30 vs Below 30

# %%
above = data[data["Age"]>=30]
below = data[data["Age"]<30]
above.loc[:, "Age"] = "Above 30"
below.loc[:, "Age"] = "Below 30"

ageData = pd.concat([below, above], axis=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='1.3 Do you believe that religious freedom (the freedom to practice religion) is guaranteed to all individuals in the place where you reside? ', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.3 Do you believe that religious freedom (the freedom to practice religion) is guaranteed to all individuals in the place where you reside? ', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='2.1 Do you believe that individuals who regularly use drugs or consume alcohol are positive contributing members of the society?', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.1 Do you believe that individuals who regularly use drugs or consume alcohol are positive contributing members of the society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='2.2 Would you have a positive or a negative reaction towards such members?', data=ageData)
plt.legend(loc="upper right")
plt.title('2.2 Would you have a positive or a negative reaction towards such members?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='2.7 How do you think your moral values and beliefs have changed over time?', data=ageData)
plt.legend(loc="upper right")
plt.title('2.7 How do you think your moral values and beliefs have changed over time?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 4)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='2.8 Do you think concerts/parties are spreading vulgarity in our society?', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.8 Do you think concerts/parties are spreading vulgarity in our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.5 Your moral views or behavior changed because of consuming media.', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.5 Your moral views or behavior changed because of consuming media.', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 3)

# %% [markdown]
# # Above 30 vs Below 30 (Only Muslims)

# %%
interIslam = ageData[ageData["Religion"]=="Islam"]

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="1.1 Do you think religion provides the complete code of conduct of a person’s life?", data=interIslam, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.1 Do you think religion provides the complete code of conduct of a person’s life?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, interIslam.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="1.2 Do you think religious freedom is everyone’s right? ", data=interIslam, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.2 Do you think religious freedom is everyone’s right? ', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, interIslam.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="1.4 Do you think people who wear modest clothes appear to be more moral.", data=interIslam, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.4 Do you think people who wear modest clothes appear to be more moral.', x=0.5, y=1.1)
with_hue(ax, interIslam.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="2.8 Do you think concerts/parties are spreading vulgarity in our society?", data=interIslam, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.8 Do you think concerts/parties are spreading vulgarity in our society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, interIslam.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="2.1 Do you believe that individuals who regularly use drugs or consume alcohol are positive contributing members of the society?", data=interIslam, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.1 Do you believe that individuals who regularly use drugs or consume alcohol are positive contributing members of the society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, interIslam.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="2.2 Would you have a positive or a negative reaction towards such members?", data=interIslam)
plt.legend(loc="upper right")
plt.title('2.2 Would you have a positive or a negative reaction towards such members?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, interIslam.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue="2.7 How do you think your moral values and beliefs have changed over time?", data=interIslam)
plt.legend(loc="upper right")
plt.title('2.7 How do you think your moral values and beliefs have changed over time?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, interIslam.Age, 2, 4)

# %% [markdown]
# #Pakistan VS Abroad

# %%
pakData = data[data["Country and city of residence"]=="Pakistan"]
otherData = data[data["Country and city of residence"]!="Pakistan"]

otherData.loc[:, "Country and city of residence"] = "Abroad"
countryData = pd.concat([pakData, otherData], axis=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue="1.2 Do you think religious freedom is everyone’s right? ", data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.2 Do you think religious freedom is everyone’s right? ', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue="1.3 Do you believe that religious freedom (the freedom to practice religion) is guaranteed to all individuals in the place where you reside? ", data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.3 Do you believe that religious freedom (the freedom to practice religion) is guaranteed to all individuals in the place where you reside? ', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue="1.4 Do you think people who wear modest clothes appear to be more moral.", data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('1.4 Do you think people who wear modest clothes appear to be more moral.', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue="2.3 Women, transgenders, minorities are given equal rights in the society you live in.", data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('2.3 Women, transgenders, minorities are given equal rights in the society you live in.', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %% [markdown]
# # Media Effects

# %% [markdown]
# Age

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
above = data[data["Age"]>=30]
below = data[data["Age"]<30]
above.loc[:, "Age"] = "Above 30"
below.loc[:, "Age"] = "Below 30"

ageData = pd.concat([below, above], axis=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
def with_hue(ax, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in ax.patches]
    patch = [p for p in ax.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x+0.1, y), size = 12)

# %%
colors = ['0 – 3 hours', '4 – 6 hours', '7 – 10 hours', "10+ hours"]
palette_colors = sns.color_palette('Set2', 4)
palette_dict = {continent: color for continent, color in zip(colors, palette_colors)}

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.1 How much time do you spend consuming media (e.g., watching TV, streaming movies, reading news articles, using social media)?', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('How much time do you spend consuming media \n (e.g., watching TV, streaming movies, reading news articles, using social media)?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 4)

# %%
colors = ['Yes', 'No', 'To some extent', "I’ve never heard about the Aurat March."]
palette_colors = sns.color_palette('Set2', 4)
palette_dict = {continent: color for continent, color in zip(colors, palette_colors)}

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.2 Have you ever encountered media content that you believe was immoral or unethical?', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.2 Have you ever encountered media content that you believe was immoral or unethical?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 2)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.3 Do you believe that the media has an impact on your personal morality or the moral values of society?', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.3 Do you believe that the media has an impact on your personal morality or \n the moral values of society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.4 Do you think that media companies have a responsibility to promote moral values in their content?', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.4 Do you think that media companies have a responsibility to promote moral values \n in their content?', x=0.5, y=1.1, fontweight="bold")

with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.5 Your moral views or behavior changed because of consuming media.', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.5 Your moral views or behavior changed because of consuming media.', x=0.5, y=1.1, fontweight="bold")

with_hue(ax, ageData.Age, 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Age', hue='3.6 You have encountered media content that you felt was biased or misleading when it came to presenting moral issues', data=ageData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.6 You have encountered media content that you felt was biased or misleading when \n it came to presenting moral issues', x=0.5, y=1.1, fontweight="bold")

with_hue(ax, ageData.Age, 2, 3)

# %% [markdown]
# Pakistan vs Others

# %%
pakData = data[data["Country and city of residence"]=="Pakistan"]
otherData = data[data["Country and city of residence"]!="Pakistan"]

otherData.loc[:, "Country and city of residence"] = "Abroad"
countryData = pd.concat([pakData, otherData], axis=0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
colors = ['0 – 3 hours', '4 – 6 hours', '7 – 10 hours', "10+ hours"]
palette_colors = sns.color_palette('Set2', 4)
palette_dict = {continent: color for continent, color in zip(colors, palette_colors)}

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue='3.1 How much time do you spend consuming media (e.g., watching TV, streaming movies, reading news articles, using social media)?', data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('How much time do you spend consuming media \n (e.g., watching TV, streaming movies, reading news articles, using social media)?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 4)

# %%
colors = ['Yes', 'No', 'To some extent', "I’ve never heard about the Aurat March."]
palette_colors = sns.color_palette('Set2', 4)
palette_dict = {continent: color for continent, color in zip(colors, palette_colors)}

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue='3.2 Have you ever encountered media content that you believe was immoral or unethical?', data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.2 Have you ever encountered media content that you believe was immoral or unethical?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 2)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue='3.3 Do you believe that the media has an impact on your personal morality or the moral values of society?', data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.3 Do you believe that the media has an impact on your personal morality or \n the moral values of society?', x=0.5, y=1.1, fontweight="bold")
with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue='3.4 Do you think that media companies have a responsibility to promote moral values in their content?', data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.4 Do you think that media companies have a responsibility to promote moral values \n in their content?', x=0.5, y=1.1, fontweight="bold")

with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue='3.5 Your moral views or behavior changed because of consuming media.', data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.5 Your moral views or behavior changed because of consuming media.', x=0.5, y=1.1, fontweight="bold")

with_hue(ax, countryData["Country and city of residence"], 2, 3)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
ax = sns.countplot(x='Country and city of residence', hue='3.6 You have encountered media content that you felt was biased or misleading when it came to presenting moral issues', data=countryData, palette=palette_dict)
plt.legend(loc="upper right")
plt.title('3.6 You have encountered media content that you felt was biased or misleading when \n it came to presenting moral issues', x=0.5, y=1.1, fontweight="bold")

with_hue(ax, countryData["Country and city of residence"], 2, 3)
